# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashv000/Machine-Learning-Lab-CS3103/blob/master/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PR curve

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=100, noise=0.3)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.rainbow)
